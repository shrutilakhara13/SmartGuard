# %%
import numpy as np
import pandas as pd

# %%
from itertools import combinations
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
# Define the path to the directory containing CSV files
dataset_csv_path = "C:\\Users\\lawan\\Capstone Project Files\\Datasets\\"

# List of CSV file names to be concatenated
csv_file_names = [
    'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',
    'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv',
    'Friday-WorkingHours-Morning.pcap_ISCX.csv',
    'Monday-WorkingHours.pcap_ISCX.csv',
    'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',
    'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',
    'Tuesday-WorkingHours.pcap_ISCX.csv',
    'Wednesday-workingHours.pcap_ISCX.csv'
]

# Create a list of full paths by joining the directory path with each CSV file name
full_path = [os.path.join(dataset_csv_path, csv_file) for csv_file in csv_file_names]

# Concatenate the DataFrames from each CSV file into a single DataFrame
df = pd.concat(map(pd.read_csv, full_path), ignore_index=True)

# %%
df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %%
print("The columns present in the dataset are: ")
df.columns
# Out:
# The columns present in the dataset are:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830743 entries, 0 to 2830742
# Data columns (total 79 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0    Destination Port             int64
#  1    Flow Duration                int64
#  2    Total Fwd Packets            int64
#  3    Total Backward Packets       int64
#  4   Total Length of Fwd Packets   int64
#  5    Total Length of Bwd Packets  int64
#  6    Fwd Packet Length Max        int64
#  7    Fwd Packet Length Min        int64
#  8    Fwd Packet Length Mean       float64
#  9    Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max         int64
#  11   Bwd Packet Length Min        int64
#  12   Bwd Packet Length Mean       float64
#  13   Bwd Packet Length Std        float64
#  14  Flow Bytes/s                  float64
#  15   Flow Packets/s               float64
#  16   Flow IAT Mean                float64
#  17   Flow IAT Std                 float64
# ...

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count       2.830743e+06    2.830743e+06        2.830743e+06
# mean        8.071483e+03    1.478566e+07        9.361160e+00
# std         1.828363e+04    3.365374e+07        7.496728e+02
# min         0.000000e+00   -1.300000e+01        1.000000e+00
# 25%         5.300000e+01    1.550000e+02        2.000000e+00
# 50%         8.000000e+01    3.131600e+04        2.000000e+00
# 75%         4.430000e+02    3.204828e+06        5.000000e+00
# max         6.553500e+04    1.200000e+08        2.197590e+05
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count             2.830743e+06                 2.830743e+06
# mean              1.039377e+01                 5.493024e+02
# std               9.973883e+02                 9.993589e+03
# min               0.000000e+00                 0.000000e+00
# 25%               1.000000e+00                 1.200000e+01
# ...

# %%
def data_cleaning(df):
    # Remove leading and trailing whitespaces from column names
    df.columns = df.columns.str.strip()
    print("Dataset Shape:", df.shape)

    # Replace negative numeric values with 0
    num = df._get_numeric_data()
    num[num < 0] = 0

    # Identify and drop columns with zero variance
    zero_variance_cols = []
    for col in df.columns:
        if len(df[col].unique()) == 1:
            zero_variance_cols.append(col)
    df.drop(columns=zero_variance_cols, axis=1, inplace=True)
    print("Zero Variance Columns:", zero_variance_cols, "are dropped!!")
    print("Shape after removing the zero variance columns:", df.shape)

    # Replace infinite values with NaN and drop rows with NaN
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    print(df.isna().any(axis=1).sum(), "rows dropped")
    df.dropna(inplace=True)
    print("Shape after Removing NaN:", df.shape)

    # Drop duplicate rows
    df.drop_duplicates(inplace=True)
    print("Shape after dropping duplicates:", df.shape)

    # Identify and drop columns with identical values
    column_pairs = [(i, j) for i, j in combinations(df, 2) if df[i].equals(df[j])]
    identical_cols = []
    for col_pair in column_pairs:
        identical_cols.append(col_pair[1])
    df.drop(columns=identical_cols, axis=1, inplace=True)
    print("Columns which have identical values:", column_pairs, "dropped!")
    print("Shape after removing identical value columns:", df.shape)

    return df

# %%
df=data_cleaning(df)
# Out:
# Dataset Shape: (2830743, 79)
# Zero Variance Columns: ['Bwd PSH Flags', 'Bwd URG Flags', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate'] are dropped!!
# Shape after removing the zero variance columns: (2830743, 71)
# 2867 rows dropped
# Shape after Removing NaN: (2827876, 71)
# Shape after dropping duplicates: (2520798, 71)
# Columns which have identical values: [('Total Fwd Packets', 'Subflow Fwd Packets'), ('Total Backward Packets', 'Subflow Bwd Packets'), ('Fwd PSH Flags', 'SYN Flag Count'), ('Fwd URG Flags', 'CWE Flag Count'), ('Fwd Header Length', 'Fwd Header Length.1')] dropped!
# Shape after removing identical value columns: (2520798, 66)

# %%
df['Label'].value_counts()
# Out:
# BENIGN                        2095057
# DoS Hulk                       172846
# DDoS                           128014
# PortScan                        90694
# DoS GoldenEye                   10286
# FTP-Patator                      5931
# DoS slowloris                    5385
# DoS Slowhttptest                 5228
# SSH-Patator                      3219
# Bot                              1948
# Web Attack � Brute Force         1470
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: Label, dtype: int64

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create a count plot for the 'Label' column, excluding 'BENIGN' entries
plot = sns.countplot(data=df['Label'], y=df['Label'].loc[df['Label'] != 'BENIGN'])

# Set the x-axis scale to logarithmic for better visibility
plt.xscale('log')

# Get the figure for saving
fig = plot.get_figure()

# Save the figure as 'label_not_benign.png'
fig.savefig('label_not_benign.png')

# Display the plot
plt.show()

# %%
from sklearn.decomposition import PCA

# Subsample the DataFrame by taking 10% of each group defined by 'Label'
subsample_df = df.groupby('Label').apply(pd.DataFrame.sample, frac=0.1).reset_index(drop=True)

# Separate features (X) and target variable (y) from the subsampled DataFrame
X = subsample_df.drop(['Label'], axis=1)
y = subsample_df['Label']

# Initialize PCA with 2 components
pca = PCA(n_components=2, random_state=0)

# Transform the features into a 2D space using PCA
z = pca.fit_transform(X)

# Create a new DataFrame for the PCA results
pca_df = pd.DataFrame()
pca_df['Label'] = y
pca_df['PCA 1'] = z[:, 0]
pca_df['PCA 2'] = z[:, 1]

# Create a scatter plot of the PCA results
# Each point is colored based on the 'Label' and the color palette is generated dynamically
sns.scatterplot(data=pca_df, x='PCA 1', y='PCA 2', hue='Label', palette=sns.color_palette('hls', len(pca_df.Label.value_counts()))).set_title("CICIDS2017 PCA Projection")

# Place the legend outside the plot for better visibility
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# %%
# Update labels in 'Label' column to 'ATTACK' for non-'BENIGN' entries
pca_df.loc[pca_df.Label != 'BENIGN', 'Label'] = 'ATTACK'

# Create a scatter plot of the updated labels
# Points are colored based on the binary classification ('ATTACK' or 'BENIGN')
sns.scatterplot(data=pca_df, x='PCA 1', y='PCA 2', hue=pca_df.Label, palette=sns.color_palette('hls', 2)).set_title("CICIDS2017 Binary Class PCA Projection")

# Place the legend outside the plot for better visibility
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# %%
# Modify column names in the DataFrame
df.columns=df.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(','').str.replace(')','')
df.head()
# Out:
# C:\Users\lawan\AppData\Local\Temp\ipykernel_856\1605416762.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(','').str.replace(')','')
# C:\Users\lawan\AppData\Local\Temp\ipykernel_856\1605416762.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(','').str.replace(')','')
#    destination_port  flow_duration  total_fwd_packets  total_backward_packets  \
# 0             54865              3                  2                       0
# ...

# %%
new_df=df.copy()

# %% [markdown]
# <h3>Considering the task as Binary Classification</h3>

# %%
# Update values in the 'label' column to 'ATTACK' for rows where the original value is not 'BENIGN'
df.loc[df['label'] != 'BENIGN', 'label'] = 'ATTACK'

# Display the updated DataFrame with the first few rows
df.head()
# Out:
#    destination_port  flow_duration  total_fwd_packets  total_backward_packets  \
# 0             54865              3                  2                       0
# 1             55054            109                  1                       1
# 2             55055             52                  1                       1
# 3             46236             34                  1                       1
# 4             54863              3                  2                       0
#
#    total_length_of_fwd_packets  total_length_of_bwd_packets  \
# 0                           12                            0
# 1                            6                            6
# 2                            6                            6
# 3                            6                            6
# 4                           12                            0
#
#    fwd_packet_length_max  fwd_packet_length_min  fwd_packet_length_mean  \
# ...

# %%
df.label.value_counts()
# Out:
# BENIGN    2095057
# ATTACK     425741
# Name: label, dtype: int64

# %%
sns.countplot(data=df,x=df['label'])
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %% [markdown]
# <h3>Balancing the dataset</h3>

# %%
# Calculate the size of the subset where the label is 'ATTACK'
size = len(df.loc[df.label == 'ATTACK'])
print("Size of 'ATTACK' subset:", size)

# Create a balanced DataFrame by sampling the same number of rows for each label
# The lambda function is used with groupby to apply the sampling to each group (label)
bal_df = df.groupby('label').apply(lambda x: x.sample(n=min(size, len(x))))

# The resulting DataFrame 'bal_df' now has an equal number of rows for each label
# Out:
# Size of 'ATTACK' subset: 425741

# %%
sns.countplot(data=bal_df,x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
bal_df.shape
# Out:
# (851482, 66)

# %%
import gc
# Manually trigger the garbage collection process
gc.collect()
# Out:
# 1722

# %%
# Update values in the 'label' column to 1 for rows where the original value is 'ATTACK'
bal_df.loc[bal_df['label'] == 'ATTACK', 'label'] = 1

# Update values in the 'label' column to 0 for rows where the original value is 'BENIGN'
bal_df.loc[bal_df['label'] == 'BENIGN', 'label'] = 0

# %%
# Import necessary modules for data preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Extract features (X) and labels (y) from the balanced DataFrame 'bal_df'
X = bal_df.drop(columns='label')  # Features: Exclude the 'label' column
y = bal_df['label'].astype('int')  # Labels: Convert to integer format for classification

# Apply Min-Max scaling to normalize feature values between 0 and 1
X = MinMaxScaler().fit_transform(X)

# %%
# Split the data into training and testing sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

# Display the shapes of the training and testing sets
print("Training set shapes - X_train:", X_train.shape, "y_train:", y_train.shape)
print("Testing set shapes - X_test:", X_test.shape, "y_test:", y_test.shape)
# Out:
# Training set shapes - X_train: (681185, 65) y_train: (681185,)
# Testing set shapes - X_test: (170297, 65) y_test: (170297,)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score, f1_score, precision_score, recall_score
def classify(model):
    # Fit the model on the training data
    model.fit(X_train, y_train)
    # Evaluate and print the accuracy on the test set
    model_score = model.score(X_test, y_test)
    print(f"Model Accuracy on Test Set: {model_score:.4f}")

    # Make predictions on the test set
    y_pred = model.predict(X_test)
    # Print the classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    # Create a figure for visualizations
    fig = plt.figure(figsize=(10, 5))
    # Plot the confusion matrix
    plt.subplot(1, 2, 1)
    cm = confusion_matrix(y_test, y_pred, normalize='true')
    sns.heatmap(cm, annot=True)
    
    # Plot the ROC curve
    plt.subplot(1, 2, 2)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    plt.plot(fpr, tpr, label='ROC Curve')
    plt.plot([0, 1], [1, 0], 'k--', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.xlim([-0.02, 1])
    plt.ylim([0, 1.02])
    plt.legend(loc='lower right')

    # Print additional metrics
    print("Additional Metrics:")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 Score:", f1_score(y_test, y_pred))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier

# %%
classify(LogisticRegression(max_iter=500))
# Out:
# Model Accuracy on Test Set: 0.9471
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95     85049
#            1       0.93      0.96      0.95     85248
#
#     accuracy                           0.95    170297
#    macro avg       0.95      0.95      0.95    170297
# weighted avg       0.95      0.95      0.95    170297
#
# Additional Metrics:
# Accuracy: 0.9471159210085909
# Precision: 0.934100847226018
# Recall: 0.9622395833333334
# F1 Score: 0.9479614477881015

# %%
classify(AdaBoostClassifier())
# Out:
# Model Accuracy on Test Set: 0.9915
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     85049
#            1       0.99      0.99      0.99     85248
#
#     accuracy                           0.99    170297
#    macro avg       0.99      0.99      0.99    170297
# weighted avg       0.99      0.99      0.99    170297
#
# Additional Metrics:
# Accuracy: 0.9914561031609482
# Precision: 0.991045580806601
# Recall: 0.991894237987988
# F1 Score: 0.9914697277934443

# %%
classify(LinearSVC())
# Out:
# C:\Users\lawan\AppData\Roaming\Python\Python310\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Model Accuracy on Test Set: 0.9485
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     85049
#            1       0.93      0.97      0.95     85248
#
#     accuracy                           0.95    170297
#    macro avg       0.95      0.95      0.95    170297
# weighted avg       0.95      0.95      0.95    170297
#
# Additional Metrics:
# Accuracy: 0.9484547584514114
# Precision: 0.9324443539630836
# Recall: 0.9670960022522522
# F1 Score: 0.9494541182974018

# %%
classify(MLPClassifier(max_iter=3000))
# Out:
# Model Accuracy on Test Set: 0.9857
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     85049
#            1       0.98      0.99      0.99     85248
#
#     accuracy                           0.99    170297
#    macro avg       0.99      0.99      0.99    170297
# weighted avg       0.99      0.99      0.99    170297
#
# Additional Metrics:
# Accuracy: 0.9856838347122967
# Precision: 0.9805148082814966
# Recall: 0.9910965653153153
# F1 Score: 0.9857772903346246

# %% [markdown]
# <h3>Taking the Unbalanced Dataset</h3>

# %%
# Convert 'ATTACK' labels to 1 and 'BENIGN' labels to 0
df.loc[df['label'] == 'ATTACK', 'label'] = 1
df.loc[df['label'] == 'BENIGN', 'label'] = 0

# Extract features (Xu) and labels (yu) from the DataFrame
Xu = df.drop(columns='label')
yu = df['label'].astype('int')

# Apply Min-Max scaling to normalize feature values between 0 and 1
Xu = MinMaxScaler().fit_transform(Xu)

# Split the data into training and testing sets
Xu_train, Xu_test, yu_train, yu_test = train_test_split(Xu, yu, test_size=0.2)

# %%
print(Xu_train.shape,yu_train.shape)
print(Xu_test.shape,yu_test.shape)
# Out:
# (2016638, 65) (2016638,)
# (504160, 65) (504160,)

# %%
def classify_unbalanced(model):
    # Fit the unbalanced model on the training data
    model.fit(Xu_train, yu_train)
    
    # Make predictions on the test set
    y_pred = model.predict(Xu_test)
    
    # Print the classification report
    print("Classification Report:")
    print(classification_report(yu_test, y_pred))

    # Create a figure for visualizations
    fig = plt.figure(figsize=(10, 5))

    # Plot the confusion matrix
    plt.subplot(1, 2, 1)
    cm = confusion_matrix(yu_test, y_pred, normalize='true')
    sns.heatmap(cm, annot=True)

    # Plot the ROC curve
    plt.subplot(1, 2, 2)
    fpr, tpr, thresholds = roc_curve(yu_test, y_pred)
    plt.plot(fpr, tpr, label='ROC Curve')
    plt.plot([0, 1], [1, 0], 'k--', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.xlim([-0.02, 1])
    plt.ylim([0, 1.02])
    plt.legend(loc='lower right')

    # Print additional metrics
    print("Additional Metrics:")
    print("Accuracy:", accuracy_score(yu_test, y_pred))
    print("Precision:", precision_score(yu_test, y_pred))
    print("Recall:", recall_score(yu_test, y_pred))
    print("F1 Score:", f1_score(yu_test, y_pred))

# %%
classify_unbalanced(LogisticRegression(max_iter=500))
# Out:
# C:\Users\lawan\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97    418670
#            1       0.85      0.84      0.84     85490
#
#     accuracy                           0.95    504160
#    macro avg       0.91      0.90      0.91    504160
# weighted avg       0.95      0.95      0.95    504160
#
# Additional Metrics:
# Accuracy: 0.947058473500476
# Precision: 0.8476063232320844
# ...

# %%
classify_unbalanced(AdaBoostClassifier())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    418670
#            1       0.99      0.98      0.98     85490
#
#     accuracy                           0.99    504160
#    macro avg       0.99      0.99      0.99    504160
# weighted avg       0.99      0.99      0.99    504160
#
# Additional Metrics:
# Accuracy: 0.9941863694065376
# Precision: 0.9897376881918163
# Recall: 0.9758334308106211
# F1 Score: 0.9827363808244836

# %%
classify_unbalanced(LinearSVC())
# Out:
# C:\Users\lawan\AppData\Roaming\Python\Python310\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    418670
#            1       0.88      0.82      0.85     85490
#
#     accuracy                           0.95    504160
#    macro avg       0.92      0.90      0.91    504160
# weighted avg       0.95      0.95      0.95    504160
#
# Additional Metrics:
# Accuracy: 0.9501983497302444
# Precision: 0.8790077581661603
# Recall: 0.8190431629430343
# F1 Score: 0.847966672318163

# %%
classify_unbalanced(MLPClassifier(max_iter=3000))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    418670
#            1       0.95      0.97      0.96     85490
#
#     accuracy                           0.99    504160
#    macro avg       0.97      0.98      0.98    504160
# weighted avg       0.99      0.99      0.99    504160
#
# Additional Metrics:
# Accuracy: 0.9861512218343383
# Precision: 0.9516106764841233
# Recall: 0.9675283658907474
# F1 Score: 0.9595035090771997

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

def classify_with_lstm(X_train, y_train, X_test, y_test):
    # Reshape the data for LSTM input
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

    # Define the LSTM model
    model = Sequential()
    model.add(LSTM(50, input_shape=(X_train.shape[1], 1)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Train the LSTM model
    model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

    # Make predictions on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")

    # Print classification report and confusion matrix
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred, normalize='true')
    sns.heatmap(cm, annot=True, fmt=".2f")

    # Additional metrics
    print("The Accuracy of the Model is", accuracy_score(y_test, y_pred))
    print("The Precision of the Model is", precision_score(y_test, y_pred))
    print("The Recall of the Model is", recall_score(y_test, y_pred))
    print("The F1 Score of the Model is", f1_score(y_test, y_pred))

# %%
classify_with_lstm(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/5
# 17030/17030 [==============================] - 433s 25ms/step - loss: 0.2265 - accuracy: 0.9018 - val_loss: 0.1716 - val_accuracy: 0.9347
# Epoch 2/5
# 17030/17030 [==============================] - 446s 26ms/step - loss: 0.1190 - accuracy: 0.9536 - val_loss: 0.0979 - val_accuracy: 0.9613
# Epoch 3/5
# 17030/17030 [==============================] - 449s 26ms/step - loss: 0.0936 - accuracy: 0.9626 - val_loss: 0.0853 - val_accuracy: 0.9655
# Epoch 4/5
# 17030/17030 [==============================] - 445s 26ms/step - loss: 0.0852 - accuracy: 0.9659 - val_loss: 0.0835 - val_accuracy: 0.9671
# Epoch 5/5
# ...
# 5322/5322 [==============================] - 45s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97     85049
#            1       0.95      0.99      0.97     85248
#
#     accuracy                           0.97    170297
#    macro avg       0.97      0.97      0.97    170297
# ...

# %%
classify_with_lstm(Xu_train, yu_train, Xu_test, yu_test)
# Out:
# Epoch 1/5
# 50416/50416 [==============================] - 1519s 30ms/step - loss: 0.1206 - accuracy: 0.9490 - val_loss: 0.0829 - val_accuracy: 0.9663
# Epoch 2/5
# 50416/50416 [==============================] - 1408s 28ms/step - loss: 0.0640 - accuracy: 0.9695 - val_loss: 0.0506 - val_accuracy: 0.9743
# Epoch 3/5
# 50416/50416 [==============================] - 1403s 28ms/step - loss: 0.0507 - accuracy: 0.9746 - val_loss: 0.0454 - val_accuracy: 0.9766
# Epoch 4/5
# 50416/50416 [==============================] - 1425s 28ms/step - loss: 0.0450 - accuracy: 0.9770 - val_loss: 0.0430 - val_accuracy: 0.9794
# Epoch 5/5
# ...
# 15755/15755 [==============================] - 138s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    418670
#            1       0.95      0.94      0.94     85490
#
#     accuracy                           0.98    504160
#    macro avg       0.97      0.96      0.97    504160
# ...
